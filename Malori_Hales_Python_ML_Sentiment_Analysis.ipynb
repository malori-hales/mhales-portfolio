# %% [markdown]
# # Machine Learning Project
# ## Using Sentiment Analysis to Classify Gender of Book Authors
#
# ## By Malori Hales
#
# In this machine learning project I have created a simple sentiment analysis model to satisfy one of my own curiosities: Is there a detectable difference in writing styles between modern male and female authors?

# %% [markdown]
# First, I will import the necessary libraries for the project.

# %%
import numpy as np    
import pandas as pd   
import re             
import nltk           
from nltk.corpus import stopwords
from sklearn.model_selection import train_test_split as tts

# %%
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/malorieve/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/malorieve/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
stop_words = set(stopwords.words('english'))

# %% [markdown]
# Now I will read in the file containing the training data as a pandas dataframe.

# %%
df = pd.read_csv("authorData2.csv")

# %%
df
# Out:
#                                                  Book  Sentiment  Word Count  \
# 0                       The Book Their - Markus Zusak          0        1143
# 1                 The Vanished Birds by Simon Jimenez          0        1694
# 2   The Small Crimes of Tiffany Templeton by Richa...          0         766
# 3                       Starsight - Brandon Sanderson          0        1885
# 4                     Looking for Alaska - John Green          0        1048
# 5                      The Kingdom of Back - Marie Lu          1         972
# 6                      Ember Queen by Laura Sebastian          1        1479
# 7             Field Notes on Love by Jennifer E Smith          1         974
# 8                         The Twin by Natasha Preston          1        1419
# 9            All the Pretty Things by Emily Arsenault          1        1782
# 10            An Abundance of Katherines - John Green          0        1211
# 11                         Chrysalis - Brendan Reichs          0        1733
# 12  Rayne and Delilah’s Midnite Matinee - Jeff Zen...          0         499
# 13                        The Between - David Hofmeyr          0        1712
# 14                       Frankly in Love - David Yoon          0        1438
# 15          The Queen’s Assassin - Melissa De La Cruz          1        1730
# 16      A Good Girl’s Guide to Murder - Holly Jackson          1        1782
# 17               One of Us is Next - Karen M. McManus          1        1340
# 18            The Fountains of Silence - Ruta Sepetys          1         485
# 19                  American Royals - Katherine McGee          1         986
# 20                          Ashlords - Scott Reintgen          0        1579
# 21                      The Good Hawk - Joseph Elliot          0         985
# 22                    Nyxia Uprising - Scott Reintgen          0        1157
# 23  The Fork, the Witch, and the Worm - Christophe...          0         976
# 24                      Bridge of Clay - Markus Zusak          0        1092
# 25           House of Sorrows and Salt - Erin A Craig          1        1052
# 26                          Wilder Girls - Rory Power          1        1165
# 27                       Aurora Rising - Amie Kaufman          1        1073
# 28                        Mermaid Moon - Susann Cokal          1         992
# 29         When You Were Everything - Ashley Woodfolk          1        1868
# 30    145th Street: Short Stories - Walter Dean Myers          0        1617
# 31                    19 Love Songs - David Leviathan          0        1629
# 32                       Point of View - Patrick Bard          0        1143
# 33                 The Book of Dust - Phillip Pullman          0        1961
# 34              Turtles All the Way Down - John Green          0        1844
# 35                     Ash Princess - Laura Sebastian          1        1004
# 36             Tempests and Slaughter - Tamora Pierce          1        1138
# 37                      Love, Hate, and Other Filters          1        1956
# 38  There’s Someone Inside Your House - Stephanie ...          1        1944
# 39                         Genuine Fraud - E Lockhart          1         950
#
#                                           Text Sample
# 0   DEATH AND CHOCOLATE\n\n\nFirst the colors.\nTh...
# 1   He was born with an eleventh finger. A small b...
# 2   The court-appointed advocate dropped me off at...
# 3   I slammed on my overburn and boosted my starsh...
# 4   “So do you really memorize last words?”\nShe r...
# 5   SALZBURG, AUSTRIA\n1759\n\nMOZART BY THE OCEAN...
# 6   Reckoning\n\n\n\nThe sun is blinding when I st...
# 7   Hugo\n\nThe shock of it takes a few minutes to...
# 8   I dig the tips of my yellow-­painted fingernai...
# 9   “Hon. Morgan is missing.” \n\n\nThat’s how Dad...
# 10  The morning after noted child prodigy Colin Si...
# 11  Back in the village we grabbed several lengths...
# 12  Here’s the thing with dreams--and I’m talking ...
# 13  Between school and home lies a path through th...
# 14  Mom-n-Dad work at The Store every day, from mo...
# 15  Something or someone is following me. I’ve bee...
# 16  Pip knew where they lived. \n\n\n\nEveryone in...
# 17  “I have to go to the football field real quick...
# 18  They stand in line for blood.\n\n\nJune’s earl...
# 19  Present Day\n\nBeatrice could trace her ancest...
# 20  Farian wakes me at some ungodly hour. \n\n\nHe...
# 21  The wind is on my nose and my eyes sting. I br...
# 22  Babel’s king bleeds.\n\nFor a moment, I think ...
# 23  The day had not gone well.\n\nEragon leaned ba...
# 24  If before the beginning (in the writing, at le...
# 25  CANDLELIGHT   REFLECTED   OFF  THE  SILVER ANC...
# 26  Something. Way out in the white-dark. Between ...
# 27  I’m gonna miss the Draft.\nThe Hadfield is dis...
# 28  The moon lowers herself to draw the tide.\n\nW...
# 29  When the train finally shows up, it’s so crowd...
# 30  The way I see it, things happen on 145th Stree...
# 31  Quiz Bowl Antichrist\n\n\nI am haunted at time...
# 32  “Lucas? Are you listening to me? You’d already...
# 33  Eleven-year-old Malcolm lives with his parents...
# 34  At the time I first realized I might be fictio...
# 35  “Thora!”\nI turn to see Crescentia barreling t...
# 36  The Imperial Coliseum, Thak City, The Carthaki...
# 37  Destiny sucks.\n     Sure, it can be all heart...
# 38  The egg-shaped timer was on the welcome mat wh...
# 39  Begin here:\n\n \nThird week in June, 2017\n\n...

# %%
men = df.loc[df['Sentiment'] == 0]
men
# Out:
#                                                  Book  Sentiment  Word Count  \
# 0                       The Book Their - Markus Zusak          0        1143
# 1                 The Vanished Birds by Simon Jimenez          0        1694
# 2   The Small Crimes of Tiffany Templeton by Richa...          0         766
# 3                       Starsight - Brandon Sanderson          0        1885
# 4                     Looking for Alaska - John Green          0        1048
# 10            An Abundance of Katherines - John Green          0        1211
# 11                         Chrysalis - Brendan Reichs          0        1733
# 12  Rayne and Delilah’s Midnite Matinee - Jeff Zen...          0         499
# 13                        The Between - David Hofmeyr          0        1712
# 14                       Frankly in Love - David Yoon          0        1438
# 20                          Ashlords - Scott Reintgen          0        1579
# 21                      The Good Hawk - Joseph Elliot          0         985
# 22                    Nyxia Uprising - Scott Reintgen          0        1157
# 23  The Fork, the Witch, and the Worm - Christophe...          0         976
# 24                      Bridge of Clay - Markus Zusak          0        1092
# 30    145th Street: Short Stories - Walter Dean Myers          0        1617
# 31                    19 Love Songs - David Leviathan          0        1629
# 32                       Point of View - Patrick Bard          0        1143
# 33                 The Book of Dust - Phillip Pullman          0        1961
# 34              Turtles All the Way Down - John Green          0        1844
#
#                                           Text Sample
# 0   DEATH AND CHOCOLATE\n\n\nFirst the colors.\nTh...
# 1   He was born with an eleventh finger. A small b...
# 2   The court-appointed advocate dropped me off at...
# 3   I slammed on my overburn and boosted my starsh...
# 4   “So do you really memorize last words?”\nShe r...
# 10  The morning after noted child prodigy Colin Si...
# 11  Back in the village we grabbed several lengths...
# 12  Here’s the thing with dreams--and I’m talking ...
# 13  Between school and home lies a path through th...
# 14  Mom-n-Dad work at The Store every day, from mo...
# 20  Farian wakes me at some ungodly hour. \n\n\nHe...
# 21  The wind is on my nose and my eyes sting. I br...
# 22  Babel’s king bleeds.\n\nFor a moment, I think ...
# 23  The day had not gone well.\n\nEragon leaned ba...
# 24  If before the beginning (in the writing, at le...
# 30  The way I see it, things happen on 145th Stree...
# 31  Quiz Bowl Antichrist\n\n\nI am haunted at time...
# 32  “Lucas? Are you listening to me? You’d already...
# 33  Eleven-year-old Malcolm lives with his parents...
# 34  At the time I first realized I might be fictio...

# %%
women = df.loc[df['Sentiment'] == 1]
women
# Out:
#                                                  Book  Sentiment  Word Count  \
# 5                      The Kingdom of Back - Marie Lu          1         972
# 6                      Ember Queen by Laura Sebastian          1        1479
# 7             Field Notes on Love by Jennifer E Smith          1         974
# 8                         The Twin by Natasha Preston          1        1419
# 9            All the Pretty Things by Emily Arsenault          1        1782
# 15          The Queen’s Assassin - Melissa De La Cruz          1        1730
# 16      A Good Girl’s Guide to Murder - Holly Jackson          1        1782
# 17               One of Us is Next - Karen M. McManus          1        1340
# 18            The Fountains of Silence - Ruta Sepetys          1         485
# 19                  American Royals - Katherine McGee          1         986
# 25           House of Sorrows and Salt - Erin A Craig          1        1052
# 26                          Wilder Girls - Rory Power          1        1165
# 27                       Aurora Rising - Amie Kaufman          1        1073
# 28                        Mermaid Moon - Susann Cokal          1         992
# 29         When You Were Everything - Ashley Woodfolk          1        1868
# 35                     Ash Princess - Laura Sebastian          1        1004
# 36             Tempests and Slaughter - Tamora Pierce          1        1138
# 37                      Love, Hate, and Other Filters          1        1956
# 38  There’s Someone Inside Your House - Stephanie ...          1        1944
# 39                         Genuine Fraud - E Lockhart          1         950
#
#                                           Text Sample
# 5   SALZBURG, AUSTRIA\n1759\n\nMOZART BY THE OCEAN...
# 6   Reckoning\n\n\n\nThe sun is blinding when I st...
# 7   Hugo\n\nThe shock of it takes a few minutes to...
# 8   I dig the tips of my yellow-­painted fingernai...
# 9   “Hon. Morgan is missing.” \n\n\nThat’s how Dad...
# 15  Something or someone is following me. I’ve bee...
# 16  Pip knew where they lived. \n\n\n\nEveryone in...
# 17  “I have to go to the football field real quick...
# 18  They stand in line for blood.\n\n\nJune’s earl...
# 19  Present Day\n\nBeatrice could trace her ancest...
# 25  CANDLELIGHT   REFLECTED   OFF  THE  SILVER ANC...
# 26  Something. Way out in the white-dark. Between ...
# 27  I’m gonna miss the Draft.\nThe Hadfield is dis...
# 28  The moon lowers herself to draw the tide.\n\nW...
# 29  When the train finally shows up, it’s so crowd...
# 35  “Thora!”\nI turn to see Crescentia barreling t...
# 36  The Imperial Coliseum, Thak City, The Carthaki...
# 37  Destiny sucks.\n     Sure, it can be all heart...
# 38  The egg-shaped timer was on the welcome mat wh...
# 39  Begin here:\n\n \nThird week in June, 2017\n\n...

# %% [markdown]
# I checked to make sure there were an equal number of male and female authors included in my training data.

# %%
print(len(men))
print(len(women))
# Out:
# 20
# 20

# %% [markdown]
# ## Defining Functions

# %%
def clean_my_text(text):
    text = re.sub(r"<.*?>", "", text)      
    text = re.sub("[^a-zA-Z]", " ", text)
    text = re.sub(r'[^\x00-\x7F]+',' ', text)
    text = text.strip().lower()            
    text = re.sub(" s ", " ", text)     
    
    tokenizer = nltk.tokenize.TreebankWordTokenizer()
    tokens = tokenizer.tokenize(text)   
    
    unstopped = []                        
    for word in tokens:
        if word not in stop_words:         
            unstopped.append(word)         
    stemmer = nltk.stem.WordNetLemmatizer()   
    cleanText = " ".join(stemmer.lemmatize(token) for token in unstopped)
    return cleanText

# %%
X_train, X_test, y_train, y_test = tts(df["Text Sample"], df["Sentiment"], test_size=0.2)

# %%
def clean_my_data(dataList):
    print("Cleaning all of the data")
    i = 0
    for textEntry in dataList:              
                                                  
        cleanElement = clean_my_text(textEntry)     
        dataList[i] = cleanElement  
        i = i + 1
        print("Cleaning entry number", i, "out of", len(dataList))
    print("Finished cleaning all of the data\n")
    return dataList


print("Operating on training data...\n")
reviews = X_train.tolist()
cleanReviewData = clean_my_data(reviews)
# Out:
# Operating on training data...
#
# Cleaning all of the data
# Cleaning entry number 1 out of 32
# Cleaning entry number 2 out of 32
# Cleaning entry number 3 out of 32
# Cleaning entry number 4 out of 32
# Cleaning entry number 5 out of 32
# Cleaning entry number 6 out of 32
# Cleaning entry number 7 out of 32
# Cleaning entry number 8 out of 32
# Cleaning entry number 9 out of 32
# Cleaning entry number 10 out of 32
# Cleaning entry number 11 out of 32
# Cleaning entry number 12 out of 32
# Cleaning entry number 13 out of 32
# Cleaning entry number 14 out of 32
# Cleaning entry number 15 out of 32
# Cleaning entry number 16 out of 32
# Cleaning entry number 17 out of 32
# Cleaning entry number 18 out of 32
# Cleaning entry number 19 out of 32
# Cleaning entry number 20 out of 32
# Cleaning entry number 21 out of 32
# Cleaning entry number 22 out of 32
# Cleaning entry number 23 out of 32
# Cleaning entry number 24 out of 32
# Cleaning entry number 25 out of 32
# Cleaning entry number 26 out of 32
# Cleaning entry number 27 out of 32
# Cleaning entry number 28 out of 32
# Cleaning entry number 29 out of 32
# Cleaning entry number 30 out of 32
# Cleaning entry number 31 out of 32
# Cleaning entry number 32 out of 32
# Finished cleaning all of the data

# %%
def create_bag_of_words(X):
    from sklearn.feature_extraction.text import CountVectorizer
    
    print ('Generating bag of words...')
    
    vectorizer = CountVectorizer(analyzer = "word",   \
                                 tokenizer = None,    \
                                 preprocessor = None, \
                                 stop_words = None,   \
                                 ngram_range = (1,2), \
                                 max_features = 10000)
                                                         
    train_data_features = vectorizer.fit_transform(X)
    train_data_features = train_data_features.toarray()
    
    from sklearn.feature_extraction.text import TfidfTransformer
    tfidf = TfidfTransformer()
    tfidf_features = tfidf.fit_transform(train_data_features)
    return vectorizer, tfidf_features, tfidf

# %%
vectorizer, tfidf_features, tfidf  = (create_bag_of_words(cleanReviewData))
# Out:
# Generating bag of words...

# %%
def train_logistic_regression(features, label):
    print ("Training the logistic regression model...")
    from sklearn.linear_model import LogisticRegression
    ml_model = LogisticRegression(C = 100, random_state = 0, solver = 'liblinear')
    ml_model.fit(features, label)
    print ('Finished training the model\n')
    return ml_model

# %% [markdown]
# ## Train and Test Model

# %%
ml_model = train_logistic_regression(tfidf_features, y_train)
# Out:
# Training the logistic regression model...
# Finished training the model

# %%
print("Operating on test data...\n")
sentiments = X_test.tolist()
cleanTestData = clean_my_data(sentiments)
# Out:
# Operating on test data...
#
# Cleaning all of the data
# Cleaning entry number 1 out of 8
# Cleaning entry number 2 out of 8
# Cleaning entry number 3 out of 8
# Cleaning entry number 4 out of 8
# Cleaning entry number 5 out of 8
# Cleaning entry number 6 out of 8
# Cleaning entry number 7 out of 8
# Cleaning entry number 8 out of 8
# Finished cleaning all of the data

# %%
test_data_features = vectorizer.transform(cleanTestData)
test_data_features = test_data_features.toarray()

# %%
test_data_tfidf_features = tfidf.fit_transform(test_data_features)
test_data_tfidf_features = test_data_tfidf_features.toarray()

# %%
predicted_y = ml_model.predict(test_data_tfidf_features)

# %%
correctly_identified_y = predicted_y == y_test
accuracy = np.mean(correctly_identified_y) * 100
print ('The accuracy of the model in predicting book author sentiment is %.0f%%' %accuracy)
# Out:
# The accuracy of the model in predicting book author sentiment is 50%
